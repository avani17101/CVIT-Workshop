# %%
import pandas as pd
import json, os
import numpy as np

df = pd.read_csv("./tmdb_5000_movies.csv")

data = {}
num_choices = 5

try:
    with open("final.json", "r") as f:
        data = json.load(f)
except:
    ip = input("Enter your name: ").strip()
    while ip == "":
        ip = input("Enter your name: ")
        
    data["username"] = ip
    data["movie_ids"] = []
    data["genre_freq"] = {}
    data["genre_freq_divided"] = {}
    
    for i in range(df.shape[0]):
        genres = json.loads(df["genres"].iloc[i])
        for genre in genres:
            data["genre_freq"][genre["name"]] = 0
            data["genre_freq_divided"][genre["name"]] = 0
            
while len(data["movie_ids"]) != df.shape[0]:
    num_idxs = min(df.shape[0]-len(data["movie_ids"]), num_choices)
    idxs = np.random.choice(df.shape[0], size=num_idxs, replace=False)
    
    print("-"*100)
    for i,idx in enumerate(idxs.tolist()):
        while df["id"].iloc[idx] in data["movie_ids"]: 
            idx = np.random.randint(0, df.shape[0])

        print("{}) {}".format(i, df["title"].iloc[idx]))

    ip = int(input("Preferred Movie: "))
    if not 0<=ip<num_choices:
        print("No option selected. Skipping...")
        continue
    
    chosen_loc = idxs[i]
    genres = json.loads(df["genres"].iloc[chosen_loc])
    for genre in genres:
        data["genre_freq"][genre["name"]] += 1
        data["genre_freq_divided"][genre["name"]] += 1/len(genres)

    data["movie_ids"].append(int(df["id"].iloc[chosen_loc]))

    with open("final.json", "w") as f:
        json.dump(data, f)
# Out:
# ----------------------------------------------------------------------------------------------------
# 0) Scream 3
# 1) Army of Darkness
# 2) Wanted
# 3) Someone Like You...
# 4) A Farewell to Arms
# Preferred Movie: 2
# ----------------------------------------------------------------------------------------------------
# 0) The Cookout
# 1) 20 Dates
# 2) Boomerang
# 3) Texas Chainsaw 3D
# 4) Wuthering Heights
# Preferred Movie: 4
# ----------------------------------------------------------------------------------------------------
# 0) Human Traffic
# 1) Sicario
# 2) Adore
# 3) Resident Evil: Afterlife
# 4) The Yellow Handkerchief
# Preferred Movie: 2
# ----------------------------------------------------------------------------------------------------
# 0) The American President
# 1) Undiscovered
# 2) Femme Fatale
# 3) Pushing Tin
# 4) Blue Valentine
# Preferred Movie: 0
# ----------------------------------------------------------------------------------------------------
# 0) Aroused
# 1) Easy Money
# 2) Censored Voices
# 3) Erin Brockovich
# 4) Tea with Mussolini
# Preferred Movie: 3
# ----------------------------------------------------------------------------------------------------
# 0) Ninja Assassin
# 1) 20,000 Leagues Under the Sea
# 2) Stuart Little 2
# 3) The Three Stooges
# 4) Persepolis
# Preferred Movie: 1
# ----------------------------------------------------------------------------------------------------
# 0) Forsaken
# 1) Chairman of the Board
# 2) The Painted Veil
# 3) Wind Walkers
# 4) Extraordinary Measures
# Preferred Movie: 2
# ----------------------------------------------------------------------------------------------------
# 0) Graduation Day
# 1) The Wrestler
# 2) White House Down
# 3) The Californians
# 4) The Sound and the Shadow
# Preferred Movie: 0
# ----------------------------------------------------------------------------------------------------
# 0) Looper
# 1) Waiting for Guffman
# 2) The Wild Thornberrys Movie
# 3) The Glimmer Man
# 4) Independence Daysaster
# Preferred Movie: 4
# ----------------------------------------------------------------------------------------------------
# 0) Paranormal Activity
# 1) Enough Said
# 2) Sea Rex 3D: Journey to a Prehistoric World
# 3) The Croods
# 4) Captive
# Preferred Movie: 2
# ----------------------------------------------------------------------------------------------------
# 0) The Fast and the Furious
# 1) Muppets Most Wanted
# 2) Like Mike
# 3) The First Great Train Robbery
# 4) Herbie Fully Loaded
# Preferred Movie: 0
# ----------------------------------------------------------------------------------------------------
# 0) Deuce Bigalow: Male Gigolo
# 1) The Sisterhood of the Traveling Pants
# 2) When the Lights Went Out
# 3) Who's Your Caddy?
# 4) Jekyll and Hyde ... Together Again
# Preferred Movie: 2
# ----------------------------------------------------------------------------------------------------
# 0
# Preferred Movie: 0
# ----------------------------------------------------------------------------------------------------
# 0) After.Life
# 1) Julie & Julia
# 2) For Greater Glory - The True Story of Cristiada
# 3) Dead Man on Campus
# 4) Spy Game
# Preferred Movie: 2
# ----------------------------------------------------------------------------------------------------
# 0) Barney's Version
# 1) Last I Heard
# 2) Black Swan
# 3) The Fog
# 4) The Legend of Hell's Gate: An American Conspiracy
# Preferred Movie: 2
# ----------------------------------------------------------------------------------------------------
# 0) Jaws 2
# 1) Hard Candy
# 2) Marvin's Room
# 3) One Missed Call
# 4) Into the Storm
# Preferred Movie: 3
# ----------------------------------------------------------------------------------------------------
# 0) Teeth and Blood
# 1) Sorcerer
# 2) Teenage Mutant Ninja Turtles: Out of the Shadows
# 3) Re-Kill
# 4) Beyond Borders
# Preferred Movie: 4
# ----------------------------------------------------------------------------------------------------
# 0) Airborne
# 1) The Lucky Ones
# 2) Sin City: A Dame to Kill For
# 3) Nothing But a Man
# 4) Hope Floats
# Preferred Movie: 4
# ----------------------------------------------------------------------------------------------------
# 0) Connie and Carla
# 1) Grudge Match
# 2) Saving Private Ryan
# 3) Takers
# 4) The Color of Money
# Preferred Movie: 2
# ----------------------------------------------------------------------------------------------------
# 0) And So It Goes
# 1) Allegiant
# 2) Shanghai Calling
# 3) Dazed and Confused
# 4) Pieces of April
# Preferred Movie: 3
# ----------------------------------------------------------------------------------------------------
# 0) The Collection
# 1) History of the World: Part I
# 2) Predators
# 3) The Lost Medallion: The Adventures of Billy Stone
# 4) What Just Happened
# Preferred Movie: 1
# ----------------------------------------------------------------------------------------------------
# 0) Crazy Heart
# 1) Point Break
# 2) Two Evil Eyes
# 3) Legend
# 4) Face/Off
# Preferred Movie: 3
# ----------------------------------------------------------------------------------------------------
# 0) The Invasion
# 1) Spotlight
# 2) Superbabies: Baby Geniuses 2
# 3) She's the Man
# 4) The Conformist
# Preferred Movie: 0
# ----------------------------------------------------------------------------------------------------
# 0) Se7en
# 1) Walking With Dinosaurs
# 2) A Charlie Brown Christmas
# 3) xXx
# 4) Dead Man's Shoes
# Preferred Movie: 4
# ----------------------------------------------------------------------------------------------------
# 0) Queen Crab
# 1) Fido
# 2) A Simple Wish
# 3) Crocodile Dundee II
# 4) The X Files: I Want to Believe
# Preferred Movie: 4
# ----------------------------------------------------------------------------------------------------
# 0) Fantastic Four
# 1) Magic Mike XXL
# 2) Me and You and Everyone We Know
# 3) Faith Like Potatoes
# 4) Six-String Samurai
# Preferred Movie: 0
# ----------------------------------------------------------------------------------------------------
# 0) Metropolis
# 1) The Midnight Meat Train
# 2) Chasing Papi
# 3) Cirque du Soleil: Worlds Away
# 4) Hotel Rwanda
# Preferred Movie: 2
# ----------------------------------------------------------------------------------------------------
# 0) Saving Mr. Banks
# 1) By the Sea
# 2) Peaceful Warrior
# 3) Friday the 13th Part III
# 4) The Reader
# Preferred Movie: 2
# ----------------------------------------------------------------------------------------------------
# 0) History of the World: Part I
# 1) Prefontaine
# 2) The Banger Sisters
# 3) Hansel & Gretel: Witch Hunters
# 4) Bolt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/lib/python3/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/lib/python3/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/lib/python3/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     466         """
# --> 467         parts = [self.recv(flags, copy=copy, track=track)]
#     468         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/lib/python3/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-772956823c46> in <module>()
#      38         print("{}) {}".format(i, df["title"].iloc[idx]))
#      39
# ---> 40     ip = int(input("Preferred Movie: "))
#      41     if not 0<=ip<num_choices:
#      42         print("No option selected. Skipping...")
#
# /usr/lib/python3/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/lib/python3/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:
